# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import FAUSTPy

# %%
dspFile = 'testSynth.dsp'

# %%
cat {dspFile}
# Out:
# import("stdfaust.lib");
# f = hslider("freq",100,10,1200,0.1);
# o = os.osc(f);
# process = o;

# %%
sr = 44100 #Hz
T = 0.1 #seconds
N = int(T*sr) #samps
n = np.arange(N)
t = n/sr

# %%
mySynth = FAUSTPy.FAUST(dspFile,sr)
# Out:
# /opt/conda/lib/python3.7/site-packages/cffi/vengine_cpy.py:192: UserWarning: reimporting '_cffi__x49ef2025xa9a1fa91' might overwrite older definitions
#   % (self.verifier.get_module_name()))
# From callback for ffi.gc <cdata 'mydsp *' 0x55b15cdbf3e0>:
# TypeError: initializer for ctype 'mydsp *' appears indeed to be 'mydsp *', but the types are different (check that you are not e.g. mixing up different ffi instances)

# %%
audio = mySynth.compute(N)

# %%
audio.shape
# Out:
# (1, 4410)

# %%
plot(audio[0,:])
title("Audio Output")
show()
